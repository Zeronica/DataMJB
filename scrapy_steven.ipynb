# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %%
headers={'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:58.0) Gecko/20100101 Firefox/58.0',
    'From': 'data-x@gmail.com' }

# %%
df = pd.DataFrame(columns=["room", "area", "price", "orient", "level", "dec", "line", "linedistance", "district", \
                           "school", "time", "elevator", "unknown1", "unknown2", "unknown3", "unknown4", "web"])

# %%
def scrapy(webs):

    room = []
    area = []
    price = []
    orient = []
    level = []
    dec = []
    line = []
    linedistance = []
    district = []
    school = []
    time = []
    elevator = []
    unknown1 = []
    unknown2 = []
    unknown3 = []
    unknown4 = []
    web = []
    df1 = pd.DataFrame(columns=["room", "area", "price", "orient", "level", "dec", "line", "linedistance", "district", \
                           "school", "time", "elevator", "unknown1", "unknown2", "unknown3", "unknown4", "web"])
    try:
        source = requests.get(webs, headers=headers).content
        soup = BeautifulSoup(source,'html.parser')
        #basci info
        d = soup.find_all(class_='tt')
        room.append(d[0].text)
        area.append(d[1].text)
        price.append(d[2].text)
        orient.append(d[3].text)
        level.append(d[4].text)
        dec.append(d[5].text)
        #other info
        d = soup.find_all(class_='rcont')
        d1 = re.findall(r'\((.*)\)', d[0].text)
        try:
            d1 = re.findall(r'[0-9]+', d1[0])
            line.append(d1[0])
            linedistance.append(d1[1])
        except:
            line.append(0)
            linedistance.append(0)
        d2 = re.findall(r'\S+', d[1].text)
        district.append(d2[0])
        web.append(webs)
        try:
            sch = soup.find(class_='rcont rcont-school').text
            school.append(1)
            del d[2]
        except:
            school.append(0)
        while not (d[2].text.startswith('19') or d[2].text.startswith('20')):
            del d[2]
        time.append(d[2].text)
        elevator.append(d[3].text)
        unknown1.append(d[4].text)
        unknown2.append(d[5].text)
        unknown3.append(d[6].text)
        unknown4.append(d[7].text)
        df1.room = room
        df1.area = area
        df1.price = price
        df1.orient = orient 
        df1.level = level
        df1.dec = dec
        df1.line = line
        df1.linedistance = linedistance
        df1.district = district
        df1.school = school
        df1.time = time
        df1.elevator = elevator
        df1.unknown1 = unknown1
        df1.unknown2 = unknown2
        df1.unknown3 = unknown3
        df1.unknown4 = unknown4
        df1.web = web
        return df1
    except:
        return pd.DataFrame(columns=["room", "area", "price", "orient", "level", "dec", "line", "linedistance", "district", \
                           "school", "time", "elevator", "unknown1", "unknown2", "unknown3", "unknown4", "web"])

# %%
#scrapy("http://esf.sh.fang.com/chushou/3_319649421.htm")
#scrapy("http://esf.sh.fang.com/chushou/3_319943960.htm")
#scrapy("http://esf.sh.fang.com/chushou/3_319935596.htm")
#http://esf.sh.fang.com/
def scrapy_page(ii, df):

    source = requests.get('http://esf.sh.fang.com/house/i3%d'%ii, headers=headers).content
    soup = BeautifulSoup(source,'html.parser')
    a = soup.find_all(class_='title')
    for num, i in enumerate(a):
        s = i.find('a').get('href')
        df = df.append(scrapy("http://esf.sh.fang.com{}".format(s)), ignore_index=True)
        if num % 10 == 0:
            print('done with number ', num+(ii-1)*30)
    

    return df

# %%
import time
for i in range(227,300):
    df = pd.read_csv('data_new.csv', index_col=0)
    df = scrapy_page(i, df)
    df.to_csv('data_new.csv', header=True)
    print('done with page %d , wait for 15s'%i)
    time.sleep(15)
# Out:
# done with number  5550
# done with number  5560
# done with number  5570
# done with page 186 , wait for 15s
# done with number  5580
# done with number  5590
# done with number  5600
# done with page 187 , wait for 15s
# done with number  5610
# done with number  5620
# done with number  5630
# done with page 188 , wait for 15s
# done with number  5640
# done with number  5650
# done with number  5660
# done with page 189 , wait for 15s
# done with number  5670
# done with number  5680
# done with number  5690
# done with page 190 , wait for 15s
# done with number  5700
# done with number  5710
# done with number  5720
# done with page 191 , wait for 15s
# done with number  5730
# done with number  5740
# done with number  5750
# done with page 192 , wait for 15s
# done with number  5760
# done with number  5770
# done with number  5780
# done with page 193 , wait for 15s
# done with number  5790
# done with number  5800
# done with number  5810
# done with page 194 , wait for 15s
# done with number  5820
# done with number  5830
# done with number  5840
# done with page 195 , wait for 15s
# done with number  5850
# done with number  5860
# done with number  5870
# done with page 196 , wait for 15s
# done with number  5880
# done with number  5890
# done with number  5900
# done with page 197 , wait for 15s
# done with number  5910
# done with number  5920
# done with number  5930
# done with page 198 , wait for 15s
# done with number  5940
# done with number  5950
# done with number  5960
# done with page 199 , wait for 15s
# done with number  5970
# done with number  5980
# done with number  5990
# done with page 200 , wait for 15s
# done with number  6000
# done with number  6010
# done with number  6020
# done with page 201 , wait for 15s
# done with number  6030
# done with number  6040
# done with number  6050
# done with page 202 , wait for 15s
# done with number  6060
# done with number  6070
# done with number  6080
# done with page 203 , wait for 15s
# done with number  6090
# done with number  6100
# done with number  6110
# done with page 204 , wait for 15s
# done with number  6120
# done with number  6130
# done with number  6140
# done with page 205 , wait for 15s
# done with number  6150
# done with number  6160
# done with number  6170
# done with page 206 , wait for 15s
# done with number  6180
# done with number  6190
# done with number  6200
# done with page 207 , wait for 15s
# done with number  6210
# done with number  6220
# done with number  6230
# done with page 208 , wait for 15s
# done with number  6240
# done with number  6250
# done with number  6260
# done with page 209 , wait for 15s
# done with number  6270
# done with number  6280
# done with number  6290
# done with page 210 , wait for 15s
# done with number  6300
# done with number  6310
# done with number  6320
# done with page 211 , wait for 15s
# done with number  6330
# done with number  6340
# done with number  6350
# done with page 212 , wait for 15s
# done with number  6360
# done with number  6370
# done with number  6380
# done with page 213 , wait for 15s
# done with number  6390
# done with number  6400
# done with number  6410
# done with page 214 , wait for 15s
# done with number  6420
# done with number  6430
# done with number  6440
# done with page 215 , wait for 15s
# done with number  6450
# done with number  6460
# done with number  6470
# done with page 216 , wait for 15s
# done with number  6480
# done with number  6490
# done with number  6500
# done with page 217 , wait for 15s
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# done with number  6510
# done with number  6520
# done with number  6530
# done with page 218 , wait for 15s
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# done with number  6540
# done with number  6550
# done with number  6560
# done with page 219 , wait for 15s
# done with number  6570
# done with number  6580
# done with number  6590
# done with page 220 , wait for 15s
# done with number  6600
# done with number  6610
# done with number  6620
# done with page 221 , wait for 15s
# done with number  6630
# done with number  6640
# done with number  6650
# done with page 222 , wait for 15s
# done with number  6660
# done with number  6670
# done with number  6680
# done with page 223 , wait for 15s
# done with number  6690
# done with number  6700
# done with number  6710
# done with page 224 , wait for 15s
# done with number  6720
# done with number  6730
# done with number  6740
# done with page 225 , wait for 15s
# done with number  6750
# done with number  6760
# done with number  6770
# done with page 226 , wait for 15s
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     356         else:
# --> 357             conn.request(method, url, **httplib_request_kw)
#     358
#
# /anaconda3/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# /anaconda3/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# /anaconda3/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# /anaconda3/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# /anaconda3/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     165     def connect(self):
# --> 166         conn = self._new_conn()
#     167         self._prepare_conn(conn)
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x10e42ecf8>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPConnectionPool(host='esf.sh.fang.com', port=80): Max retries exceeded with url: /house/i3227 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10e42ecf8>: Failed to establish a new connection: [Errno 61] Connection refused',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-8-6711e0733843> in <module>()
#       2 for i in range(186,300):
#       3     df = pd.read_csv('data_new.csv', index_col=0)
# ----> 4     df = scrapy_page(i, df)
#       5     df.to_csv('data_new.csv', header=True)
#       6     print('done with page %d , wait for 15s'%i)
#
# <ipython-input-4-84dee32c03dc> in scrapy_page(ii, df)
#       5 def scrapy_page(ii, df):
#       6
# ----> 7     source = requests.get('http://esf.sh.fang.com/house/i3%d'%ii, headers=headers).content
#       8     soup = BeautifulSoup(source,'html.parser')
#       9     a = soup.find_all(class_='title')
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     506                 raise SSLError(e, request=request)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#     510         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='esf.sh.fang.com', port=80): Max retries exceeded with url: /house/i3227 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10e42ecf8>: Failed to establish a new connection: [Errno 61] Connection refused',))
