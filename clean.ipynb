# %%
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_csv('data_populated_all.csv')

# %%
step1 = data.replace(u'暂无数据', np.nan).dropna().iloc[:, 6:]
step1
# Out:
#                 0                                               link  \
# 0            汤臣一品       https://shanghai.anjuke.com/community/view/8
# 1          中粮海景壹号  https://shanghai.anjuke.com/community/view/218807
# 4            长岛花苑    https://shanghai.anjuke.com/community/view/2679
# 5         陆家嘴国际华城     https://shanghai.anjuke.com/community/view/174
# 8        碧云国际社区晓园     https://shanghai.anjuke.com/community/view/100
# 9            金谊河畔   https://shanghai.anjuke.com/community/view/13910
# 12         万科金色雅筑   https://shanghai.anjuke.com/community/view/62413
# 13     世茂滨江花园(南区)   https://shanghai.anjuke.com/community/view/14987
# 17           云台小区   https://shanghai.anjuke.com/community/view/98633
# 18     世茂湖滨花园(公寓)      https://shanghai.anjuke.com/community/view/38
# 20            星河湾  https://shanghai.anjuke.com/community/view/200907
# 23         盛大金磐花园      https://shanghai.anjuke.com/community/view/31
# 33           浦发御园  https://shanghai.anjuke.com/community/view/370266
# ...

# %%
[i for i in step1['Property type']].index(step1['Property type'].unique()[4])
# Out:
# 1448

# %%
step1
# Out:
#                 0                                               link  \
# 0            汤臣一品       https://shanghai.anjuke.com/community/view/8
# 1          中粮海景壹号  https://shanghai.anjuke.com/community/view/218807
# 4            长岛花苑    https://shanghai.anjuke.com/community/view/2679
# 5         陆家嘴国际华城     https://shanghai.anjuke.com/community/view/174
# 8        碧云国际社区晓园     https://shanghai.anjuke.com/community/view/100
# 9            金谊河畔   https://shanghai.anjuke.com/community/view/13910
# 12         万科金色雅筑   https://shanghai.anjuke.com/community/view/62413
# 13     世茂滨江花园(南区)   https://shanghai.anjuke.com/community/view/14987
# 17           云台小区   https://shanghai.anjuke.com/community/view/98633
# 18     世茂湖滨花园(公寓)      https://shanghai.anjuke.com/community/view/38
# 20            星河湾  https://shanghai.anjuke.com/community/view/200907
# 23         盛大金磐花园      https://shanghai.anjuke.com/community/view/31
# 33           浦发御园  https://shanghai.anjuke.com/community/view/370266
# ...

# %%
step2 = step1.iloc[:[i for i in step1['Property type']].index(step1['Property type'].unique()[2]),:]

# %%
step2
# Out:
#                0                                               link  \
# 0           汤臣一品       https://shanghai.anjuke.com/community/view/8
# 1         中粮海景壹号  https://shanghai.anjuke.com/community/view/218807
# 4           长岛花苑    https://shanghai.anjuke.com/community/view/2679
# 5        陆家嘴国际华城     https://shanghai.anjuke.com/community/view/174
# 8       碧云国际社区晓园     https://shanghai.anjuke.com/community/view/100
# 9           金谊河畔   https://shanghai.anjuke.com/community/view/13910
# 12        万科金色雅筑   https://shanghai.anjuke.com/community/view/62413
# 13    世茂滨江花园(南区)   https://shanghai.anjuke.com/community/view/14987
# 17          云台小区   https://shanghai.anjuke.com/community/view/98633
# 18    世茂湖滨花园(公寓)      https://shanghai.anjuke.com/community/view/38
# 20           星河湾  https://shanghai.anjuke.com/community/view/200907
# 23        盛大金磐花园      https://shanghai.anjuke.com/community/view/31
# 33          浦发御园  https://shanghai.anjuke.com/community/view/370266
# ...

# %%
def del_c(word):
    if word == []:
        return np.nan
    return word[0]

for j in step2.columns[6:13]:
    step2.loc[:,j] = [del_c(re.findall(r"[0-9]+", i)) for i in step2[j]]
# Out:
# /Users/rhett/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
step3 = step2.drop('type', axis = 1).iloc[:, 2:].dropna()
step3
# Out:
#            long          la Property type Property costs Total area  \
# 0     31.238608  121.508381            公寓             15     141894
# 1     31.236882  121.510280            公寓             12     116605
# 4     31.270386  121.609057            公寓              1      23000
# 5     31.241847  121.542053            公寓              2     200000
# 8     31.247269  121.598271            公寓              3      50000
# 9     31.146520  121.522219            公寓              1     250000
# 12    31.149503  121.524971            公寓              2      85000
# 13    31.225557  121.520885            公寓              5      40000
# 17    31.187561  121.505749            公寓              0      10000
# 18    31.236906  121.583282            公寓              5     260000
# 20    31.198809  121.542355            公寓              4      95000
# 23    31.237461  121.512641            公寓              2     114588
# 33    31.153149  121.541175            公寓              3      75624
# ...

# %%
len(step3['Property management company'].unique())
# Out:
# 855

# %%
len(step3['Developer Company'].unique())
# Out:
# 922
